# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
rng = np.random.RandomState(0)
n_samples = 500
cov = [[3, 3], [3, 4]]
X = rng.multivariate_normal(mean=[0, 0], cov=cov, size=n_samples)
pca = PCA(n_components=2).fit(X)

# %%
plt.scatter(X[:, 0], X[:, 1], alpha=0.3, label="samples")
for i, (comp, var) in enumerate(zip(pca.components_, pca.explained_variance_)):
    comp = comp * var  # scale component by its variance explanation power
    plt.plot(
        [0, comp[0]],
        [0, comp[1]],
        label=f"Component {i}",
        linewidth=5,
        color=f"C{i + 2}",
    )
plt.gca().set(
    aspect="equal",
    title="2-dimensional dataset with principal components",
    xlabel="first feature",
    ylabel="second feature",
)
plt.legend()
plt.show()

# %%
np.mean(X[:,0])
# Out:
# 0.1210555458059635

# %%
np.std(X[:,0])
# Out:
# 1.6851815045033205

# %%
np.mean(X[:,1])
# Out:
# 0.11655373596164745

# %%
np.std(X[:,1])
# Out:
# 1.9541215819331448

# %%
np.mean(pca.transform(X)[:,0])
# Out:
# 1.4210854715202004e-17

# %%
np.std(pca.transform(X)[:,0])
# Out:
# 2.4899646816691345

# %%
np.mean(pca.transform(X)[:,1])
# Out:
# -5.5067062021407764e-17

# %%
np.std(pca.transform(X)[:,1])
# Out:
# 0.6771290454095849

# %%
plt.scatter(pca.transform(X)[:,0],pca.transform(X)[:,1])
plt.xlabel("PC 1")
plt.ylabel("PC 2")
# Out:
# Text(0, 0.5, 'PC 2')

# %%
pca.explained_variance_ratio_
# Out:
# array([0.93113934, 0.06886066])

# %%
pca.explained_variance_
# Out:
# array([6.21234881, 0.45942259])

# %%
plt.scatter(X[:,0],X[:,1])
plt.scatter(pca.transform(X)[:,0]*pca.components_[0][0],pca.transform(X)[:,0]*pca.components_[0][1])
plt.scatter(pca.transform(X)[:,1]*pca.components_[1][0],pca.transform(X)[:,1]*pca.components_[1][1])
plt.xlabel("feature 1")
plt.ylabel("feature 2")
# Out:
# Text(0, 0.5, 'feature 2')

# %%
pca.components_[0]
# Out:
# array([-0.64402153, -0.76500736])
